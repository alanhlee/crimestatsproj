# %% [markdown]
# # Baton Rouge, LA

# %%
import pandas as pd

# %%
#dont seem to have reported on date

# %%
baton_rouge = pd.read_csv("../Baton_Rouge_Data/Baton_Rouge_Crime_Incidents.csv", parse_dates=['OFFENSE DATE']) 
#, dtype = {0 : "string"}, parse_dates= {"occurred" : [1, 2]})
#retrieved on 7/10/21
# Out:
# C:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
baton_rouge.columns = baton_rouge.columns.str.lower().str.replace(" ", "_")

# %%
baton_rouge = baton_rouge.rename(columns={'offense_date': 'date', 'crime': 'crime_category', 'offense_description': 'crime_description'})

# %%
baton_rouge['city'] = 'Baton Rouge'

# %%
baton_rouge = baton_rouge.loc[:, ['city', 'date', 'crime_category', 'crime_description']]

# %%
baton_rouge
# Out:
#                city       date  crime_category          crime_description
# 0       Baton Rouge 2020-04-11  SEXUAL ASSAULT                BATT/SEXUAL
# 1       Baton Rouge 2019-10-28        JUVENILE         IND BEHAVIOR W/JUV
# 2       Baton Rouge 2019-11-05  SEXUAL ASSAULT                BATT/SEXUAL
# 3       Baton Rouge 2019-11-09  SEXUAL ASSAULT          RAPE/ATT FORCIBLE
# 4       Baton Rouge 2020-03-14        JUVENILE         IND BEHAVIOR W/JUV
# ...             ...        ...             ...                        ...
# 490573  Baton Rouge 2012-05-12           THEFT  THEFT OVER $200 ALL OTHER
# 490574  Baton Rouge 2018-01-07           OTHER        CHILD RESTRAINT REQ
# 490575  Baton Rouge 2020-08-30         ASSAULT          ASSAULT/SIMPLE/CC
# 490576  Baton Rouge 2012-10-04         FIREARM        FELON IN POSS F/ARM
# 490577  Baton Rouge 2019-01-31           OTHER                SPEEDING/CC
#
# [490578 rows x 4 columns]

# %%
baton_rouge
# Out:
#                city       date  crime_category          crime_description
# 0       Baton Rouge 2020-04-11  SEXUAL ASSAULT                BATT/SEXUAL
# 1       Baton Rouge 2019-10-28        JUVENILE         IND BEHAVIOR W/JUV
# 2       Baton Rouge 2019-11-05  SEXUAL ASSAULT                BATT/SEXUAL
# 3       Baton Rouge 2019-11-09  SEXUAL ASSAULT          RAPE/ATT FORCIBLE
# 4       Baton Rouge 2020-03-14        JUVENILE         IND BEHAVIOR W/JUV
# ...             ...        ...             ...                        ...
# 490573  Baton Rouge 2012-05-12           THEFT  THEFT OVER $200 ALL OTHER
# 490574  Baton Rouge 2018-01-07           OTHER        CHILD RESTRAINT REQ
# 490575  Baton Rouge 2020-08-30         ASSAULT          ASSAULT/SIMPLE/CC
# 490576  Baton Rouge 2012-10-04         FIREARM        FELON IN POSS F/ARM
# 490577  Baton Rouge 2019-01-31           OTHER                SPEEDING/CC
#
# [490578 rows x 4 columns]

# %%
baton_rouge = baton_rouge[baton_rouge.date >= '2020-10-02']

# %%
baton_rouge
# Out:
#                city       date               crime_category  \
# 11      Baton Rouge 2020-11-17               SEXUAL ASSAULT
# 117     Baton Rouge 2020-10-03               SEXUAL ASSAULT
# 149     Baton Rouge 2020-11-27                     JUVENILE
# 157     Baton Rouge 2020-11-20                        THEFT
# 163     Baton Rouge 2020-11-05                     JUVENILE
# ...             ...        ...                          ...
# 490472  Baton Rouge 2020-10-14                        THEFT
# 490494  Baton Rouge 2020-10-10  CRIMINAL DAMAGE TO PROPERTY
# 490496  Baton Rouge 2020-12-19                    NARCOTICS
# 490545  Baton Rouge 2020-10-18                        THEFT
# 490569  Baton Rouge 2020-12-20                        THEFT
#
#                 crime_description
# 11                    BATT/SEXUAL
# 117              BATT/ORAL SEXUAL
# 149            IND BEHAVIOR W/JUV
# 157          ISS WORTHLESS CHECKS
# 163            CARNAL KNOW OF JUV
# ...

# %%
baton_rouge.to_csv("../Data_Clean/Baton_Rouge.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-f8acc3389ce1> in <module>
# ----> 1 baton_rouge.to_csv("Data_Clean/Baton_Rouge.csv")
#
# C:\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ...
