# %%
import pandas as pd
df = pd.read_csv('../CRIME_CATEGORIES_BINNED.csv')
df2 = pd.read_csv('../Data_Clean/Atlanta.csv')

# %%
df
# Out:
#          city                            crime_category_original  \
# 0     Atlanta                    AGG ASSAULT|AGG ASSAULT|Atlanta
# 1     Atlanta                      AUTO THEFT|AUTO THEFT|Atlanta
# 2     Atlanta                          BURGLARY|BURGLARY|Atlanta
# 3     Atlanta                          HOMICIDE|HOMICIDE|Atlanta
# 4     Atlanta                            LARCENY|LARCENY|Atlanta
# ...       ...                                                ...
# 7418  Seattle  SEX OFFENSES|Sexual Assault With An Object|Sea...
# 7419  Seattle                        SEX OFFENSES|Sodomy|Seattle
# 7420  Seattle  STOLEN PROPERTY OFFENSES|Stolen Property Offen...
# 7421  Seattle  TRESPASS OF REAL PROPERTY|Trespass of Real Pro...
# 7422  Seattle  WEAPON LAW VIOLATIONS|Weapon Law Violations|Se...
#
#                                          crime_category
# 0                                      ASSAULT OFFENSES
# 1     LARCENY/THEFT OFFENSES/STOLEN PROPERTY OFFENSE...
# ...

# %%
df2['UC2_Literal']
# Out:
# 0                 AGG ASSAULT
# 1         LARCENY-NON VEHICLE
# 2         LARCENY-NON VEHICLE
# 3        LARCENY-FROM VEHICLE
# 4                 AGG ASSAULT
#                  ...
# 17442    LARCENY-FROM VEHICLE
# 17443     LARCENY-NON VEHICLE
# 17444              AUTO THEFT
# 17445                BURGLARY
# 17446    LARCENY-FROM VEHICLE
# Name: UC2_Literal, Length: 17447, dtype: object

# %%
df2
# Out:
#        Unnamed: 0             occurred  offense_id    rpt_date   poss_date  \
# 0               0     11/29/2020 19:21   203341346  2020-12-31  11/29/2020
# 1               1     12/28/2020 17:21   203631200  2020-12-31  12/28/2020
# 2               2     12/24/2020 14:00   203631285  2020-12-31  12/24/2020
# 3               3     12/30/2020 20:15   203651634  2020-12-31  12/30/2020
# 4               4      12/31/2020 1:15   203660108  2020-12-31  12/31/2020
# ...           ...                  ...         ...         ...         ...
# 17442       17442  2021-07-01 05:36:00   211820352  2021-07-01    7/1/2021
# 17443       17443  2021-07-01 05:59:00   211820363  2021-07-01    7/1/2021
# 17444       17444  2021-07-01 03:00:00   211820373  2021-07-01    7/1/2021
# 17445       17445  2021-06-29 21:56:00   211820429  2021-07-01   6/29/2021
# 17446       17446  2021-06-30 17:00:00   211820458  2021-07-01    7/1/2021
#
# ...

# %%
df['crime_category_original'].unique()
# Out:
# array(['AGG ASSAULT|AGG ASSAULT|Atlanta', 'AUTO THEFT|AUTO THEFT|Atlanta',
#        'BURGLARY|BURGLARY|Atlanta', ...,
#        'STOLEN PROPERTY OFFENSES|Stolen Property Offenses|Seattle',
#        'TRESPASS OF REAL PROPERTY|Trespass of Real Property|Seattle',
#        'WEAPON LAW VIOLATIONS|Weapon Law Violations|Seattle'],
#       dtype=object)
