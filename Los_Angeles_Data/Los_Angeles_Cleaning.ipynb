# %% [markdown]
# # Los Angeles, CA

# %%
import pandas as pd
la = pd.read_csv('Crime_Data_from_2020_to_Present.csv', parse_dates=['Date Rptd'])

# %%
la.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  201220752  09/16/2020 12:00:00 AM  09/16/2020 12:00:00 AM      1230    12
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2  77th Street         1259         2     745
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO  Adult Other
# ...

# %%
la.columns = la.columns.str.lower().str.replace(" ", "_")

# %%
la.count()
# Out:
# dr_no             297373
# date_rptd         297373
# date_occ          297373
# time_occ          297373
# area              297373
# area_name         297373
# rpt_dist_no       297373
# part_1-2          297373
# crm_cd            297373
# crm_cd_desc       297373
# mocodes           256660
# vict_age          297373
# vict_sex          258446
# vict_descent      258441
# premis_cd         297367
# premis_desc       297269
# weapon_used_cd    108770
# weapon_desc       108770
# status            297373
# status_desc       297373
# crm_cd_1          297371
# crm_cd_2           24329
# crm_cd_3             832
# crm_cd_4              31
# location          297373
# cross_street       53340
# lat               297373
# lon               297373
# dtype: int64

# %%
la = la.rename(columns={'dr_no': 'city', 'date_rptd': 'date', 'crm_cd_desc': 'crime_category'})

# %%
la['city'] = 'Los Angeles'

# %%
la = la.loc[:, ['city', 'date', 'crime_category']]

# %%
la = la[la.date >= '2020-10-19']

# %%
la.to_csv('../Data_Clean/Los_Angeles.csv')
# Out:
#                city       date                                  crime_category
# 130     Los Angeles 2020-12-08        SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 166     Los Angeles 2021-06-02                               THEFT OF IDENTITY
# 204     Los Angeles 2020-11-10               INTIMATE PARTNER - SIMPLE ASSAULT
# 257     Los Angeles 2020-11-01  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 273     Los Angeles 2021-05-06                               THEFT OF IDENTITY
# ...             ...        ...                                             ...
# 297368  Los Angeles 2021-05-28                                     TRESPASSING
# 297369  Los Angeles 2021-07-04                        BATTERY - SIMPLE ASSAULT
# 297370  Los Angeles 2021-03-19                                VEHICLE - STOLEN
# 297371  Los Angeles 2021-03-04                              FALSE IMPRISONMENT
# 297372  Los Angeles 2021-02-22                                VEHICLE - STOLEN
#
# ...
