# %% [markdown]
# # Dallas, TX

# %%
import pandas as pd
dallas = pd.read_csv('Police_Incidents.csv', parse_dates=['Date1 of Occurrence'])
# Out:
# C:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (41,52,57,64) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dallas.columns = dallas.columns.str.lower().str.replace(" ", "_")

# %%
dallas.columns
# Out:
# Index(['incident_number_w/year', 'year_of_incident', 'service_number_id',
#        'watch', 'call_(911)_problem', 'type_of_incident', 'type__location',
#        'type_of_property', 'incident_address', 'apartment_number',
#        'reporting_area', 'beat', 'division', 'sector', 'council_district',
#        'target_area_action_grids', 'community', 'date1_of_occurrence',
#        'year1_of_occurrence', 'month1_of_occurence', 'day1_of_the_week',
#        'time1_of_occurrence', 'day1_of_the_year', 'date2_of_occurrence_',
#        'year2_of_occurrence', 'month2_of_occurence', 'day2_of_the_week',
#        'time2_of_occurrence', 'day2_of_the_year', 'date_of_report',
#        'date_incident_created', 'offense_entered_year',
#        'offense_entered_month', 'offense_entered_day_of_the_week',
#        'offense_entered_time', 'offense_entered__date/time', 'cfs_number',
#        'call_received_date_time', 'call_date_time', 'call_cleared_date_time',
#        'call_dispatch_date_time', 'special_report_(pre-rms)',
#        'person_involvement_type', 'victim_type', 'victim_name', 'victim_race',
#        'victim_ethnicity', 'victim_gender', 'victim_age',
#        'victim_age_at_offense', 'victim_home_address', 'victim_apartment',
#        'victim_zip_code', 'victim_city', 'victim_state',
#        'victim_business_name', 'victim_business_address',
#        'victim_business_phone', 'responding_officer_#1__badge_no',
#        'responding_officer_#1__name', 'responding_officer_#2_badge_no',
#        'responding_officer_#2__name', 'reporting_officer_badge_no',
#        'assisting_officer_badge_no', 'reviewing_officer_badge_no',
#        'element_number_assigned', 'investigating_unit_1',
#        'investigating_unit_2', 'offense_status', 'ucr_disposition',
#        'victim_injury_description', 'victim_condition', 'modus_operandi_(mo)',
#        'family_offense', 'hate_crime', 'hate_crime_description', 'weapon_used',
#        'gang_related_offense', 'victim_package', 'drug_related_istevencident',
#        'rms_code', 'criminal_justice_information_service_code', 'penal_code',
#        'ucr_offense_name', 'ucr_offense_description', '_ucr_code',
#        'offense_type', 'nibrs_crime', 'nibrs_crime_category',
#        'nibrs_crime_against', 'nibrs_code', 'nibrs_group', 'nibrs_type',
#        'update_date', 'x_coordinate', 'y_cordinate', 'zip_code', 'city',
#        'state', 'location1'],
#       dtype='object')

# %%
dallas.head()
# Out:
#   incident_number_w/year  year_of_incident service_number_id  watch  \
# 0            231703-2016              2016    231703-2016-01      1
# 1            035860-2019              2019    035860-2019-01      3
# 2            040250-2020              2020    040250-2020-01      2
# 3            065826-2019              2019    065826-2019-01      1
# 4            033439-2019              2019    033439-2019-01      2
#
#      call_(911)_problem                         type_of_incident  \
# 0  11V - BURG MOTOR VEH  BMV (OF AUTO ACCESSORY) (P.C. 30.04(A))
# 1  11V - BURG MOTOR VEH                                      BMV
# 2         40/01 - OTHER           UNEXPLAINED DEATH (NO OFFENSE)
# 3      27 - DEAD PERSON           UNEXPLAINED DEATH (NO OFFENSE)
# 4         40/01 - OTHER           UNEXPLAINED DEATH (NO OFFENSE)
#
#           type__location type_of_property        incident_address  \
# 0  Apartment Parking Lot              NaN            13525 KIT LN
# 1                    NaN              NaN     1300 N FITZHUGH AVE
# 2                    NaN              NaN       8728 FENCHURCH RD
# 3                    NaN              NaN  5353 KELLER SPRINGS RD
# 4                    NaN              NaN      11209 LANEWOOD CIR
#
#   apartment_number  ...  nibrs_code  nibrs_group      nibrs_type  \
# 0              207  ...         NaN          NaN             NaN
# 1              NaN  ...         23F            A           Coded
# 2              NaN  ...         999            C  999 - No Coded
# 3              714  ...         999            C  999 - No Coded
# 4              NaN  ...         999            C  999 - No Coded
#
#                    update_date  x_coordinate   y_cordinate zip_code    city  \
# 0  2016-10-04 07:56:32.0000000  2.501256e+06  7.026086e+06  75240.0  DALLAS
# 1  2019-03-01 12:35:25.0000000  2.499307e+06  6.979369e+06  75204.0  DALLAS
# 2  2020-07-03 11:11:28.0000000  2.516451e+06  7.003242e+06  75238.0  DALLAS
# 3  2019-05-02 20:59:53.0000000  2.484702e+06  7.039812e+06  75248.0  DALLAS
# 4  2019-05-02 20:23:11.0000000  2.524465e+06  6.999501e+06  75218.0  DALLAS
#
#    state                                          location1
# 0     TX  13525 KIT LN\nDALLAS, TX 75240\n(32.930649, -9...
# 1     TX  1300 N FITZHUGH AVE\nDALLAS, TX 75204\n(32.802...
# 2     TX  8728 FENCHURCH RD\nDALLAS, TX 75238\n(32.86773...
# 3     TX  5353 KELLER SPRINGS RD\nDALLAS, TX 75248\n(32....
# 4     TX  11209 LANEWOOD CIR\nDALLAS, TX 75218\n(32.8567...
#
# [5 rows x 100 columns]

# %%
dallas = dallas.rename(columns={'type_of_incident': 'crime_category', 'date1_of_occurrence': 'date'})

# %%
dallas['city'] = 'Dallas'

# %%
dallas = dallas.loc[:, ['city', 'date', 'crime_category', 'victim_race', 'victim_ethnicity', 'victim_gender', 'victim_age']]

# %%
dallas.to_csv('../Data_Clean/Dallas.csv')
# Out:
#           city       date                                     crime_category  \
# 0       Dallas 2016-09-25            BMV (OF AUTO ACCESSORY) (P.C. 30.04(A))
# 1       Dallas 2019-02-21                                                BMV
# 2       Dallas 2020-02-29                     UNEXPLAINED DEATH (NO OFFENSE)
# 3       Dallas 2019-04-02                     UNEXPLAINED DEATH (NO OFFENSE)
# 4       Dallas 2019-02-18                     UNEXPLAINED DEATH (NO OFFENSE)
# ...        ...        ...                                                ...
# 794285  Dallas 2016-03-19                         ASSAULT -OFFENSIVE CONTACT
# 794286  Dallas 2016-09-18  TRAF VIO - DUTY ON STRIKE UNATTENDED (PARKED) ...
# 794287  Dallas 2015-10-28                                    RECKLESS DAMAGE
# 794288  Dallas 2014-09-20                                    RECKLESS DAMAGE
# 794289  Dallas 2015-01-14         UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE
#
#                victim_race        victim_ethnicity victim_gender  victim_age
# 0       Hispanic or Latino      Hispanic or Latino          Male        29.0
# 1                    White  Non-Hispanic or Latino        Female        40.0
# 2                    White  Non-Hispanic or Latino        Female        82.0
# 3                    White  Non-Hispanic or Latino        Female        74.0
# 4                    White  Non-Hispanic or Latino          Male        93.0
# ...                    ...                     ...           ...         ...
# 794285               White  Non-Hispanic or Latino        Female        35.0
# 794286  Hispanic or Latino      Hispanic or Latino          Male        30.0
# 794287               White  Non-Hispanic or Latino        Female        57.0
# 794288  Hispanic or Latino      Hispanic or Latino          Male        40.0
# 794289                 NaN                     NaN           NaN         NaN
#
# [794290 rows x 7 columns]
